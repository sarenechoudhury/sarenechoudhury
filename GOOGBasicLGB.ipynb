# %%
import sys
# !{sys.executable} -m pip3 install lightgbm
# Out:
# /usr/local/bin/python3: No module named pip3

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import warnings
import sklearn
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("GOOGLE.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 1     2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2     2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 3     2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 4     2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...          ...         ...         ...         ...         ...         ...
# 4912  2024-02-26  143.449997  143.839996  138.740005  138.750000  138.750000
# 4913  2024-02-27  139.410004  140.490005  138.500000  140.100006  140.100006
# 4914  2024-02-28  139.100006  139.279999  136.639999  137.429993  137.429993
# 4915  2024-02-29  138.350006  139.949997  137.570007  139.779999  139.779999
# 4916  2024-03-01  139.500000  140.000000  138.425003  138.880005  138.880005
#
#          Volume
# 0     897427216
# 1     458857488
# 2     366857939
# 3     306396159
# 4     184645512
# ...         ...
# 4912   33513000
# 4913   22364000
# 4914   30628700
# 4915   35447100
# 4916    8633007
#
# [4917 rows x 7 columns]

# %%
x = list(df.drop('Close', axis=1).columns)
y = ['Close']
x
# Out:
# ['Date', 'Open', 'High', 'Low', 'Adj Close', 'Volume']

# %%
train=df.sample(frac=0.8,random_state=200)
predict=df.drop(train.index)
train
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1503  2010-08-09  12.509362  12.590308  12.487195  12.586572  12.586572
# 2321  2013-11-06  25.544254  25.579123  25.289459  25.473270  25.473270
# 4121  2020-12-31  86.771004  87.946503  86.771004  87.594002  87.594002
# 1602  2010-12-29  14.993800  15.004011  14.917087  14.968893  14.968893
# 830   2007-12-05  17.253578  17.408001  17.123318  17.397539  17.397539
# ...          ...        ...        ...        ...        ...        ...
# 1187  2009-05-07  10.064775  10.086942   9.775858   9.878224   9.878224
# 1644  2011-03-01  15.386826  15.422692  14.926552  14.962915  14.962915
# 3125  2017-01-18  40.290501  40.310249  40.049500  40.303501  40.303501
# 1002  2008-08-12  12.503135  12.606000  12.403509  12.518328  12.518328
# 3782  2019-08-28  58.085499  58.820999  57.865002  58.550999  58.550999
#
#          Volume
# 1503   75168699
# 2321   36652871
# 4121   20238000
# 1602   40920808
# 830   169015145
# ...         ...
# 1187  120441759
# 1644  133426247
# 3125   25888000
# 1002  110641162
# 3782   16040000
#
# [3934 rows x 7 columns]

# %%
new_train = lgb.Dataset(train[x], train[y])
new_predict = lgb.Dataset(predict[x], predict[y])

# %%
params = {
    "objective": "binary",
    "boosting_type": "rf",
    "num_leaves": 5,
    "force_row_wise": True,
    "learning_rate": 0.5,
    "metric": "binary_logloss",
    "bagging_fraction": 0.8,
    "feature_fraction": 0.8,
    'num_grad_quant_bins': 4
}
